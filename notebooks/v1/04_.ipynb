# %%
import pandas as pd

test = pd.read_csv('../data/fe/test_fe_kisu.csv')

# %%
test_pred = model.predict_proba(test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 test_pred = model.predict_proba(test)
#
# NameError: name 'model' is not defined
